# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm

# %%
train_data = pd.read_csv("../data/train.csv")
test_data = pd.read_csv("../data/test.csv")

# %%
display(train_data.shape)
display(test_data.shape)
# Out:
# (11504798, 12)
# (7669866, 11)

# %% [markdown]
# # Data Preprocessing

# %%
# 필요 없는 변수 제거
train_data.drop(['id'], axis=1, inplace=True)
test_data.drop(['id'], axis=1, inplace=True)

# %%
# 범주형 변수 object로 변환
# 범주형 데이터 int -> object로 변환
train_data['Driving_License'] = train_data['Driving_License'].astype('object')
train_data['Region_Code'] = train_data['Region_Code'].astype('object')
train_data['Previously_Insured'] = train_data['Previously_Insured'].astype('object')
train_data['Policy_Sales_Channel'] = train_data['Policy_Sales_Channel'].astype('object')
#train_data['Response'] = train_data['Response'].astype('object')

test_data['Driving_License'] = test_data['Driving_License'].astype('object')
test_data['Region_Code'] = test_data['Region_Code'].astype('object')
test_data['Previously_Insured'] = test_data['Previously_Insured'].astype('object')
test_data['Policy_Sales_Channel'] = test_data['Policy_Sales_Channel'].astype('object')

# %%
# 데이터 분할
x_train = train_data.drop(['Response'], axis=1)
y_train = train_data['Response']
x_test = test_data

# 범주형 데이터 더미처리
x_train = pd.get_dummies(x_train)
x_test = pd.get_dummies(x_test)

# %%
# 학습 데이터와 테스트 데이터에서 동일한 컬럼을 유지
x_train, x_test = x_train.align(x_test, join='outer', axis=1, fill_value=0)

# %%
# 데이터 샘플링 (예: 10% 데이터만 사용)
sample_fraction = 0.01  # 샘플 비율 (1%)
x_sample, y_sample = x_train[:int(sample_fraction * len(x_train))], y_train[:int(sample_fraction * len(y_train))]

# %%
# 모델 불러오기
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split


# 모델 정의
model = RandomForestClassifier()

# Val DataSet으로 성능 확인
x_tr, x_val, y_tr, y_val = train_test_split(x_sample, y_sample, test_size=0.3, random_state=42)

# 모델 학습
model.fit(x_tr, y_tr)
# Out:
# RandomForestClassifier()

# %%
# 예측
y_pred = model.predict(x_val)

# 성능 확인
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score, roc_auc_score
#display(accuracy_score(y_val, y_pred))
#display(f1_score(y_val, y_pred))
#display(recall_score(y_val, y_pred))
#display(precision_score(y_val, y_pred))
display(roc_auc_score(y_val, y_pred))
# Out:
# 0.5579392189063478

# %%
from pycaret.classification import *

# %%
import mlflow

# %%
pycaretData = pd.concat([x_sample, y_sample], axis=1)

# %%
pycaretData
# Out:
#         Age  Annual_Premium  Driving_License_0  Driving_License_1  \
# 0        21         65101.0              False               True
# 1        43         58911.0              False               True
# 2        25         38043.0              False               True
# 3        35          2630.0              False               True
# 4        36         31951.0              False               True
# ...     ...             ...                ...                ...
# 115042   46         23178.0              False               True
# 115043   50         40512.0              False               True
# 115044   23         24953.0              False               True
# 115045   25          2630.0              False               True
# 115046   27         30441.0              False               True
#
#         Gender_Female  Gender_Male  Policy_Sales_Channel_1.0  \
# 0               False         True                     False
# 1               False         True                     False
# 2                True        False                     False
# 3                True        False                     False
# 4                True        False                     False
# ...               ...          ...                       ...
# 115042          False         True                     False
# 115043          False         True                     False
# 115044          False         True                     False
# 115045           True        False                     False
# 115046           True        False                     False
#
#         Policy_Sales_Channel_10.0  Policy_Sales_Channel_100.0  \
# 0                           False                       False
# 1                           False                       False
# 2                           False                       False
# 3                           False                       False
# 4                           False                       False
# ...                           ...                         ...
# 115042                      False                       False
# 115043                      False                       False
# 115044                      False                       False
# 115045                      False                       False
# 115046                      False                       False
#
#         Policy_Sales_Channel_101.0  ...  Region_Code_7.0  Region_Code_8.0  \
# 0                            False  ...            False            False
# 1                            False  ...            False            False
# 2                            False  ...            False            False
# 3                            False  ...            False            False
# 4                            False  ...            False            False
# ...                            ...  ...              ...              ...
# 115042                       False  ...            False            False
# 115043                       False  ...            False            False
# 115044                       False  ...            False            False
# 115045                       False  ...            False            False
# 115046                       False  ...            False             True
#
#         Region_Code_9.0  Vehicle_Age_1-2 Year  Vehicle_Age_< 1 Year  \
# 0                 False                  True                 False
# 1                 False                 False                 False
# 2                 False                 False                  True
# 3                 False                  True                 False
# 4                 False                  True                 False
# ...                 ...                   ...                   ...
# 115042            False                  True                 False
# 115043            False                  True                 False
# 115044            False                 False                  True
# 115045            False                 False                  True
# 115046            False                 False                  True
#
#         Vehicle_Age_> 2 Years  Vehicle_Damage_No  Vehicle_Damage_Yes  Vintage  \
# 0                       False              False                True      187
# 1                        True              False                True      288
# 2                       False               True               False      254
# 3                       False              False                True       76
# 4                       False               True               False      294
# ...                       ...                ...                 ...      ...
# 115042                  False              False                True      274
# 115043                  False              False                True      146
# 115044                  False              False                True      210
# 115045                  False               True               False      193
# 115046                  False               True               False      282
#
#         Response
# 0              0
# 1              1
# 2              0
# 3              0
# 4              0
# ...          ...
# 115042         0
# 115043         1
# 115044         0
# 115045         0
# 115046         0
#
# [115047 rows x 223 columns]

# %%
# SETUP
exp = setup(pycaretData, target='Response',numeric_features=['Age', 'Annual_Premium'], normalize=True)
#데이터 : data
#타겟 : class 열
#numeric_features : d_ct, ip_ct 열을 숫자형 열로 인식 시키기 위해 설정 (안할시 카테고리 열로 인식함)
# Out:
# <style type="text/css">
# #T_454fd_row8_col1, #T_454fd_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_454fd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_454fd_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_454fd_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_454fd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_454fd_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_454fd_row0_col1" class="data row0 col1" >4923</td>
#     </tr>
#     <tr>
#       <th id="T_454fd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_454fd_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_454fd_row1_col1" class="data row1 col1" >Response</td>
#     </tr>
#     <tr>
#       <th id="T_454fd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_454fd_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_454fd_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_454fd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_454fd_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_454fd_row3_col1" class="data row3 col1" >(115047, 223)</td>
#     </tr>
#     <tr>
#       <th id="T_454fd_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_454fd_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_454fd_row4_col1" class="data row4 col1" >(115047, 223)</td>
#     </tr>
#     <tr>
#       <th id="T_454fd_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_454fd_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_454fd_row5_col1" class="data row5 col1" >(80532, 223)</td>
#     </tr>
#     <tr>
#       <th id="T_454fd_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_454fd_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_454fd_row6_col1" class="data row6 col1" >(34515, 223)</td>
#     </tr>
#     <tr>
#       <th id="T_454fd_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_454fd_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_454fd_row7_col1" class="data row7 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_454fd_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_454fd_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_454fd_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_454fd_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_454fd_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_454fd_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_454fd_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_454fd_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_454fd_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_454fd_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_454fd_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_454fd_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_454fd_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_454fd_row12_col0" class="data row12 col0" >Normalize</td>
#       <td id="T_454fd_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_454fd_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_454fd_row13_col0" class="data row13 col0" >Normalize method</td>
#       <td id="T_454fd_row13_col1" class="data row13 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_454fd_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_454fd_row14_col0" class="data row14 col0" >Fold Generator</td>
#       <td id="T_454fd_row14_col1" class="data row14 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_454fd_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_454fd_row15_col0" class="data row15 col0" >Fold Number</td>
#       <td id="T_454fd_row15_col1" class="data row15 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_454fd_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_454fd_row16_col0" class="data row16 col0" >CPU Jobs</td>
#       <td id="T_454fd_row16_col1" class="data row16 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_454fd_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_454fd_row17_col0" class="data row17 col0" >Use GPU</td>
#       <td id="T_454fd_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_454fd_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_454fd_row18_col0" class="data row18 col0" >Log Experiment</td>
#       <td id="T_454fd_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_454fd_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_454fd_row19_col0" class="data row19 col0" >Experiment Name</td>
#       <td id="T_454fd_row19_col1" class="data row19 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_454fd_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_454fd_row20_col0" class="data row20 col0" >USI</td>
#       <td id="T_454fd_row20_col1" class="data row20 col1" >579c</td>
#     </tr>
#   </tbody>
# </table>

# %%
compare_models()
# Out:
# <style type="text/css">
# #T
level0_row6" class="row_heading level0 row6" >lda</th>
#       <td id="T_e3718_row6_col0" class
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=4923, reg_alpha=0.0, reg_lambda=0.0, subsample=1.0,
#                subsample_for_bin=200000, subsample_freq=0)

# %%
model = create_model('lightgbm')
# Out:
# <style type="text/css">
# #T_dd0e1_row10_col0, #T_dd0e1_row10_col1, #T_dd0e1_row10_col2, #T_dd0e1_row10_col3, #T_dd0e1_row10_col4, #T_dd0e1_row10_col5, #T_dd0e1_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_dd0e1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dd0e1_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_dd0e1_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_dd0e1_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_dd0e1_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_dd0e1_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_dd0e1_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_dd0e1_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dd0e1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dd0e1_row0_col0" class="data row0 col0" >0.8792</td>
#       <td id="T_dd0e1_row0_col1" class="data row0 col1" >0.8716</td>
#       <td id="T_dd0e1_row0_col2" class="data row0 col2" >0.0245</td>
#       <td id="T_dd0e1_row0_col3" class="data row0 col3" >0.5714</td>
#       <td id="T_dd0e1_row0_col4" class="data row0 col4" >0.0470</td>
#       <td id="T_dd0e1_row0_col5" class="data row0 col5" >0.0374</td>
#       <td id="T_dd0e1_row0_col6" class="data row0 col6" >0.0997</td>
#     </tr>
#     <tr>
#       <th id="T_dd0e1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dd0e1_row1_col0" class="data row1 col0" >0.8789</td>
#       <td id="T_dd0e1_row1_col1" class="data row1 col1" >0.8641</td>
#       <td id="T_dd0e1_row1_col2" class="data row1 col2" >0.0419</td>
#       <td id="T_dd0e1_row1_col3" class="data row1 col3" >0.5256</td>
#       <td id="T_dd0e1_row1_col4" class="data row1 col4" >0.0776</td>
#       <td id="T_dd0e1_row1_col5" class="data row1 col5" >0.0607</td>
#       <td id="T_dd0e1_row1_col6" class="data row1 col6" >0.1223</td>
#     </tr>
#     <tr>
#       <th id="T_dd0e1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dd0e1_row2_col0" class="data row2 col0" >0.8782</td>
#       <td id="T_dd0e1_row2_col1" class="data row2 col1" >0.8597</td>
#       <td id="T_dd0e1_row2_col2" class="data row2 col2" >0.0337</td>
#       <td id="T_dd0e1_row2_col3" class="data row2 col3" >0.4783</td>
#       <td id="T_dd0e1_row2_col4" class="data row2 col4" >0.0630</td>
#       <td id="T_dd0e1_row2_col5" class="data row2 col5" >0.0478</td>
#       <td id="T_dd0e1_row2_col6" class="data row2 col6" >0.1016</td>
#     </tr>
#     <tr>
#       <th id="T_dd0e1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_dd0e1_row3_col0" class="data row3 col0" >0.8784</td>
#       <td id="T_dd0e1_row3_col1" class="data row3 col1" >0.8643</td>
#       <td id="T_dd0e1_row3_col2" class="data row3 col2" >0.0286</td>
#       <td id="T_dd0e1_row3_col3" class="data row3 col3" >0.4912</td>
#       <td id="T_dd0e1_row3_col4" class="data row3 col4" >0.0541</td>
#       <td id="T_dd0e1_row3_col5" class="data row3 col5" >0.0413</td>
#       <td id="T_dd0e1_row3_col6" class="data row3 col6" >0.0956</td>
#     </tr>
#     <tr>
#       <th id="T_dd0e1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_dd0e1_row4_col0" class="data row4 col0" >0.8794</td>
#       <td id="T_dd0e1_row4_col1" class="data row4 col1" >0.8637</td>
#       <td id="T_dd0e1_row4_col2" class="data row4 col2" >0.0297</td>
#       <td id="T_dd0e1_row4_col3" class="data row4 col3" >0.5686</td>
#       <td id="T_dd0e1_row4_col4" class="data row4 col4" >0.0564</td>
#       <td id="T_dd0e1_row4_col5" class="data row4 col5" >0.0449</td>
#       <td id="T_dd0e1_row4_col6" class="data row4 col6" >0.1093</td>
#     </tr>
#     <tr>
#       <th id="T_dd0e1_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_dd0e1_row5_col0" class="data row5 col0" >0.8798</td>
#       <td id="T_dd0e1_row5_col1" class="data row5 col1" >0.8644</td>
#       <td id="T_dd0e1_row5_col2" class="data row5 col2" >0.0276</td>
#       <td id="T_dd0e1_row5_col3" class="data row5 col3" >0.6279</td>
#       <td id="T_dd0e1_row5_col4" class="data row5 col4" >0.0528</td>
#       <td id="T_dd0e1_row5_col5" class="data row5 col5" >0.0430</td>
#       <td id="T_dd0e1_row5_col6" class="data row5 col6" >0.1135</td>
#     </tr>
#     <tr>
#       <th id="T_dd0e1_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_dd0e1_row6_col0" class="data row6 col0" >0.8807</td>
#       <td id="T_dd0e1_row6_col1" class="data row6 col1" >0.8723</td>
#       <td id="T_dd0e1_row6_col2" class="data row6 col2" >0.0276</td>
#       <td id="T_dd0e1_row6_col3" class="data row6 col3" >0.7500</td>
#       <td id="T_dd0e1_row6_col4" class="data row6 col4" >0.0532</td>
#       <td id="T_dd0e1_row6_col5" class="data row6 col5" >0.0450</td>
#       <td id="T_dd0e1_row6_col6" class="data row6 col6" >0.1289</td>
#     </tr>
#     <tr>
#       <th id="T_dd0e1_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_dd0e1_row7_col0" class="data row7 col0" >0.8795</td>
#       <td id="T_dd0e1_row7_col1" class="data row7 col1" >0.8609</td>
#       <td id="T_dd0e1_row7_col2" class="data row7 col2" >0.0276</td>
#       <td id="T_dd0e1_row7_col3" class="data row7 col3" >0.6000</td>
#       <td id="T_dd0e1_row7_col4" class="data row7 col4" >0.0527</td>
#       <td id="T_dd0e1_row7_col5" class="data row7 col5" >0.0425</td>
#       <td id="T_dd0e1_row7_col6" class="data row7 col6" >0.1097</td>
#     </tr>
#     <tr>
#       <th id="T_dd0e1_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_dd0e1_row8_col0" class="data row8 col0" >0.8797</td>
#       <td id="T_dd0e1_row8_col1" class="data row8 col1" >0.8561</td>
#       <td id="T_dd0e1_row8_col2" class="data row8 col2" >0.0266</td>
#       <td id="T_dd0e1_row8_col3" class="data row8 col3" >0.6190</td>
#       <td id="T_dd0e1_row8_col4" class="data row8 col4" >0.0509</td>
#       <td id="T_dd0e1_row8_col5" class="data row8 col5" >0.0413</td>
#       <td id="T_dd0e1_row8_col6" class="data row8 col6" >0.1102</td>
#     </tr>
#     <tr>
#       <th id="T_dd0e1_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_dd0e1_row9_col0" class="data row9 col0" >0.8783</td>
#       <td id="T_dd0e1_row9_col1" class="data row9 col1" >0.8657</td>
#       <td id="T_dd0e1_row9_col2" class="data row9 col2" >0.0306</td>
#       <td id="T_dd0e1_row9_col3" class="data row9 col3" >0.4918</td>
#       <td id="T_dd0e1_row9_col4" class="data row9 col4" >0.0577</td>
#       <td id="T_dd0e1_row9_col5" class="data row9 col5" >0.0441</td>
#       <td id="T_dd0e1_row9_col6" class="data row9 col6" >0.0990</td>
#     </tr>
#     <tr>
#       <th id="T_dd0e1_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_dd0e1_row10_col0" class="data row10 col0" >0.8792</td>
#       <td id="T_dd0e1_row10_col1" class="data row10 col1" >0.8643</td>
#       <td id="T_dd0e1_row10_col2" class="data row10 col2" >0.0298</td>
#       <td id="T_dd0e1_row10_col3" class="data row10 col3" >0.5724</td>
#       <td id="T_dd0e1_row10_col4" class="data row10 col4" >0.0565</td>
#       <td id="T_dd0e1_row10_col5" class="data row10 col5" >0.0448</td>
#       <td id="T_dd0e1_row10_col6" class="data row10 col6" >0.1090</td>
#     </tr>
#     <tr>
#       <th id="T
td>
#     </tr>
#     <tr>
#       <th id="T_83247_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_83247_row5_col0" class="data row5 col0" >0.8789</td>
#       <td id="T_83247_row5_col1" class="data row5 col1" >0.8591</td>
#       <td id="T_83247_row5_col2" class="data row5 col2" >0.0235</td>
#       <td id="T_83247_row5_col3" class="data row5 col3" >0.5476</td>
#       <td id="T_83247_row5_col4" class="data row5 col4" >0.0451</td>
#       <td id="T_83247_row5_col5" class="data row5 col5" >0.0354</td>
#       <td id="T_83247_row5_col6" class="data row5 col6" >0.0944</td>
#     </tr>
#     <tr>
#       <th id="T_83247_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_83247_row6_col0" class="data row6 col0" >0.8798</td>
#       <td id="T_83247_row6_col1" class="data row6 col1" >0.8694</td>
#       <td id="T_83247_row6_col2" class="data row6 col2" >0.0215</td>
#       <td id="T_83247_row6_col3" class="data row6 col3" >0.6774</td>
#       <td id="T_83247_row6_col4" class="data row6 col4" >0.0416</td>
#       <td id="T_83247_row6_col5" class="data row6 col5" >0.0344</td>
#       <td id="T_83247_row6_col6" class="data row6 col6" >0.1057</td>
#     </tr>
#     <tr>
#       <th id="T_83247_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_83247_row7_col0" class="data row7 col0" >0.8794</td>
#       <td id="T_83247_row7_col1" class="data row7 col1" >0.8582</td>
#       <td id="T_83247_row7_col2" class="data row7 col2" >0.0245</td>
#       <td id="T_83247_row7_col3" class="data row7 col3" >0.6000</td>
#       <td id="T_83247_row7_col4" class="data row7 col4" >0.0471</td>
#       <td id="T_83247_row7_col5" class="data row7 col5" >0.0379</td>
#       <td id="T_83247_row7_col6" class="data row7 col6" >0.1034</td>
#     </tr>
#     <tr>
#       <th id="T_83247_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_83247_row8_col0" class="data row8 col0" >0.8778</td>
#       <td id="T_83247_row8_col1" class="data row8 col1" >0.8540</td>
#       <td id="T_83247_row8_col2" class="data row8 col2" >0.0143</td>
#       <td id="T_83247_row8_col3" class="data row8 col3" >0.4242</td>
#       <td id="T_83247_row8_col4" class="data row8 col4" >0.0277</td>
#       <td id="T_83247_row8_col5" class="data row8 col5" >0.0199</td>
#       <td id="T_83247_row8_col6" class="data row8 col6" >0.0594</td>
#     </tr>
#     <tr>
#       <th id="T_83247_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_83247_row9_col0" class="data row9 col0" >0.8782</td>
#       <td id="T_83247_row9_col1" class="data row9 col1" >0.8601</td>
#       <td id="T_83247_row9_col2" class="data row9 col2" >0.0245</td>
#       <td id="T_83247_row9_col3" class="data row9 col3" >0.4800</td>
#       <td id="T_83247_row9_col4" class="data row9 col4" >0.0466</td>
#       <td id="T_83247_row9_col5" class="data row9 col5" >0.0352</td>
#       <td id="T_83247_row9_col6" class="data row9 col6" >0.0867</td>
#     </tr>
#     <tr>
#       <th id="T_83247_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_83247_row10_col0" class="data row10 col0" >0.8790</td>
#       <td id="T_83247_row10_col1" class="data row10 col1" >0.8612</td>
#       <td id="T_83247_row10_col2" class="data row10 col2" >0.0242</td>
#       <td id="T_83247_row10_col3" class="data row10 col3" >0.5478</td>
#       <td id="T_83247_row10_col4" class="data row10 col4" >0.0463</td>
#       <td id="T_83247_row10_col5" class="data row10 col5" >0.0364</td>
#       <td id="T_83247_row10_col6" class="data row10 col6" >0.0954</td>
#     </tr>
#     <tr>
#       <th id="T_83247_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_83247_row11_col0" class="data row11 col0" >0.0006</td>
#       <td id="T_83247_row11_col1" class="data row11 col1" >0.0050</td>
#       <td id="T_83247_row11_col2" class="data row11 col2" >0.0042</td>
#       <td id="T_83247_row11_col3" class="data row11 col3" >0.0669</td>
#       <td id="T_83247_row11_col4
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %%
plot_model(model)
